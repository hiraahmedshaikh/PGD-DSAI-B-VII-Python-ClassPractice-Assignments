# %%
DOB = int(input("Date of Birth: "))
MOB = int(input("Month of Birth: "))
# Out:
# Date of Birth: 22
# Month of Birth: 10

# %%
print("the sum of {} and {} is {}" .fortmat(DOB , MOB , DOB + MOB))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-0ce7fd5e5efa> in <cell line: 1>()
# ----> 1 print("the sum of {} and {} is {}" .fortmat(DOB , MOB , DOB + MOB))
#
# AttributeError: 'str' object has no attribute 'fortmat'

# %%
1/=3
# Out:
#   File "<ipython-input-11-83e23b2ecd89>", line 1
#     1/=3
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %%
1**=3
# Out:
#   File "<ipython-input-12-c2cd807011aa>", line 1
#     1**=3
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %%
for n in range(1, 13): #Static
  i=n*2
  print("2 *" , n , "=", i)
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 2 * 11 = 22
# 2 * 12 = 24

# %%
i=int(input("Enter the number : ")) #Dynamic

for n in range(1, 13):
  a = n
  n *= i
  print(f"{i} x {a} = {n}")
# Out:
# Enter the number : 13
# 13 x 1 = 13
# 13 x 2 = 26
# 13 x 3 = 39
# 13 x 4 = 52
# 13 x 5 = 65
# 13 x 6 = 78
# 13 x 7 = 91
# 13 x 8 = 104
# 13 x 9 = 117
# 13 x 10 = 130
# 13 x 11 = 143
# 13 x 12 = 156

# %%
i=int(input("Enter the number : ")) #Dynamic

for n in range(1, 13):
  print(f"{i} x {n} = {i*n}")
# Out:
# Enter the number : 15
# 15 x 1 = 15
# 15 x 2 = 30
# 15 x 3 = 45
# 15 x 4 = 60
# 15 x 5 = 75
# 15 x 6 = 90
# 15 x 7 = 105
# 15 x 8 = 120
# 15 x 9 = 135
# 15 x 10 = 150
# 15 x 11 = 165
# 15 x 12 = 180
