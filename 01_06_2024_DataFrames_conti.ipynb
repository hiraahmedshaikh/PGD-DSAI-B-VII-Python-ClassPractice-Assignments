# %% [markdown]
# DATA SETS AND FRAMES

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'], 30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}
data
# Out:
# {'App': ['App_1',
#   'App_2',
#   'App_3',
#   'App_4',
#   'App_5',
#   'App_6',
#   'App_7',
#   'App_8',
#   'App_9',
#   'App_10',
#   'App_11',
#   'App_12',
#   'App_13',
#   'App_14',
#   'App_15',
#   'App_16',
#   'App_17',
#   'App_18',
#   'App_19',
#   'App_20',
#   'App_21',
#   'App_22',
#   'App_23',
#   'App_24',
#   'App_25',
#   'App_26',
#   'App_27',
#   'App_28',
#   'App_29',
#   'App_30'],
#  'Category': array(['Game', 'Education', 'Game', 'Game', 'Productivity', 'Game',
#         'Health', 'Health', 'Health', 'Health', 'Game', 'Education',
#         'Productivity', 'Productivity', 'Health', 'Education', 'Game',
#         'Health', 'Health', 'Education', 'Health', 'Health',
#         'Productivity', 'Game', 'Game', 'Health', 'Education', 'Game',
#         'Education', 'Productivity'], dtype='<U12'),
#  'Rating': array([4.8, 2.6, 3.8, 2.8, 4.6, 1.1, 2.2, 2.6, 1. , 4. , 3.8, 2.3, 4.5,
#         3.3, 4.8, 2.5, 4.8, 2. , 4.5, 3.9, 1.8, 3.4, 1.4, 4.8, 1.4, 4.3,
# ...

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 0    App_1          Game     4.8     8073                 20M   50,000+  Paid
# 1    App_2     Education     2.6     6813                 30M    1,000+  Free
# 2    App_3          Game     3.8     4658                 10M   50,000+  Paid
# 3    App_4          Game     2.8     5646                 20M   10,000+  Free
# 4    App_5  Productivity     4.6     8496                 30M  100,000+  Paid
# 5    App_6          Game     1.1     1416                 10M    1,000+  Free
# 6    App_7        Health     2.2     9243                 10M   50,000+  Paid
# 7    App_8        Health     2.6     1149  Varies with device   10,000+  Free
# 8    App_9        Health     1.0     1242                 30M  100,000+  Free
# 9   App_10        Health     4.0     3596                 20M   10,000+  Paid
# 10  App_11          Game     3.8     7444                 20M    1,000+  Free
# ...

# %%
df.head()  #first 5 data rows
# Out:
#      App      Category  Rating  Reviews Size  Installs  Type Price  \
# 0  App_1          Game     4.8     8073  20M   50,000+  Paid  9.99
# 1  App_2     Education     2.6     6813  30M    1,000+  Free  2.99
# 2  App_3          Game     3.8     4658  10M   50,000+  Paid     0
# 3  App_4          Game     2.8     5646  20M   10,000+  Free  4.99
# 4  App_5  Productivity     4.6     8496  30M  100,000+  Paid  2.99
#
#   Content Rating
# 0           Teen
# 1   Everyone 10+
# 2   Everyone 10+
# 3     Mature 17+
# 4   Everyone 10+

# %%
df.tail() #last 5 data rows
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 25  App_26        Health     4.3     8053                 10M   50,000+  Free
# 26  App_27     Education     3.2      707  Varies with device  100,000+  Free
# 27  App_28          Game     1.3     9940                 20M   50,000+  Free
# 28  App_29     Education     3.1     6254  Varies with device   10,000+  Free
# 29  App_30  Productivity     1.5     8459                 10M  100,000+  Free
#
#    Price Content Rating
# 25  0.99   Everyone 10+
# 26  2.99     Mature 17+
# 27  4.99   Everyone 10+
# 28  0.99       Everyone
# 29  4.99       Everyone

# %%
df.head(10)
# Out:
#       App      Category  Rating  Reviews                Size  Installs  Type  \
# 0   App_1          Game     4.8     8073                 20M   50,000+  Paid
# 1   App_2     Education     2.6     6813                 30M    1,000+  Free
# 2   App_3          Game     3.8     4658                 10M   50,000+  Paid
# 3   App_4          Game     2.8     5646                 20M   10,000+  Free
# 4   App_5  Productivity     4.6     8496                 30M  100,000+  Paid
# 5   App_6          Game     1.1     1416                 10M    1,000+  Free
# 6   App_7        Health     2.2     9243                 10M   50,000+  Paid
# 7   App_8        Health     2.6     1149  Varies with device   10,000+  Free
# 8   App_9        Health     1.0     1242                 30M  100,000+  Free
# 9  App_10        Health     4.0     3596                 20M   10,000+  Paid
#
#   Price Content Rating
# 0  9.99           Teen
# 1  2.99   Everyone 10+
# 2     0   Everyone 10+
# 3  4.99     Mature 17+
# ...

# %%
df.info() #metadata or characteristics of data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int64
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 2.2+ KB

# %%
df['Price'] #accessing a column in data
# Out:
# 0     9.99
# 1     2.99
# 2        0
# 3     4.99
# 4     2.99
# 5        0
# 6     1.99
# 7     4.99
# 8     2.99
# 9     5.99
# 10    9.99
# 11    9.99
# 12    2.99
# 13    5.99
# 14    0.99
# 15    2.99
# 16    4.99
# 17    0.99
# 18    5.99
# 19    5.99
# 20    2.99
# 21    4.99
# 22    2.99
# 23    2.99
# 24    9.99
# 25    0.99
# 26    2.99
# 27    4.99
# 28    0.99
# 29    4.99
# Name: Price, dtype: object

# %%
df['App']
# Out:
# 0      App_1
# 1      App_2
# 2      App_3
# 3      App_4
# 4      App_5
# 5      App_6
# 6      App_7
# 7      App_8
# 8      App_9
# 9     App_10
# 10    App_11
# 11    App_12
# 12    App_13
# 13    App_14
# 14    App_15
# 15    App_16
# 16    App_17
# 17    App_18
# 18    App_19
# 19    App_20
# 20    App_21
# 21    App_22
# 22    App_23
# 23    App_24
# 24    App_25
# 25    App_26
# 26    App_27
# 27    App_28
# 28    App_29
# 29    App_30
# Name: App, dtype: object

# %%
df['App'].replace('App_1','FoodPanda')
# Out:
# 0     FoodPanda
# 1         App_2
# 2         App_3
# 3         App_4
# 4         App_5
# 5         App_6
# 6         App_7
# 7         App_8
# 8         App_9
# 9        App_10
# 10       App_11
# 11       App_12
# 12       App_13
# 13       App_14
# 14       App_15
# 15       App_16
# 16       App_17
# 17       App_18
# 18       App_19
# 19       App_20
# 20       App_21
# 21       App_22
# 22       App_23
# 23       App_24
# 24       App_25
# 25       App_26
# 26       App_27
# 27       App_28
# 28       App_29
# 29       App_30
# Name: App, dtype: object

# %%
df['Price'].replace('0','Free')
# Out:
# 0     9.99
# 1     2.99
# 2     Free
# 3     4.99
# 4     2.99
# 5     Free
# 6     1.99
# 7     4.99
# 8     2.99
# 9     5.99
# 10    9.99
# 11    9.99
# 12    2.99
# 13    5.99
# 14    0.99
# 15    2.99
# 16    4.99
# 17    0.99
# 18    5.99
# 19    5.99
# 20    2.99
# 21    4.99
# 22    2.99
# 23    2.99
# 24    9.99
# 25    0.99
# 26    2.99
# 27    4.99
# 28    0.99
# 29    4.99
# Name: Price, dtype: object

# %%
playstore_apps = [
    "Facebook",
    "Instagram",
    "WhatsApp Messenger",
    "TikTok",
    "Snapchat",
    "Spotify",
    "Netflix",
    "YouTube",
    "Gmail",
    "Google Maps",
    "Amazon Shopping",
    "Twitter",
    "Zoom",
    "Microsoft Teams",
    "Disney+",
    "Pinterest",
    "Reddit",
    "LinkedIn",
    "Uber",
    "Airbnb",
    "Google Drive",
    "Microsoft Word",
    "Google Photos",
    "Dropbox",
    "Evernote",
    "Skype",
    "Telegram",
    "Slack",
    "Tinder",
    "Duolingo"
]

# %%
df['App'] = playstore_apps

# %%
df
# Out:
#                    App      Category  Rating  Reviews                Size  \
# 0             Facebook          Game     4.8     8073                 20M
# 1            Instagram     Education     2.6     6813                 30M
# 2   WhatsApp Messenger          Game     3.8     4658                 10M
# 3               TikTok          Game     2.8     5646                 20M
# 4             Snapchat  Productivity     4.6     8496                 30M
# 5              Spotify          Game     1.1     1416                 10M
# 6              Netflix        Health     2.2     9243                 10M
# 7              YouTube        Health     2.6     1149  Varies with device
# 8                Gmail        Health     1.0     1242                 30M
# 9          Google Maps        Health     4.0     3596                 20M
# 10     Amazon Shopping          Game     3.8     7444                 20M
# 11             Twitter     Education     2.3     5514                 30M
# ...

# %%
df['Content Rating']=df["Content Rating"].replace("Mature 17+","Mature18+")
df
# Out:
#                    App      Category  Rating  Reviews                Size  \
# 0             Facebook          Game     4.8     8073                 20M
# 1            Instagram     Education     2.6     6813                 30M
# 2   WhatsApp Messenger          Game     3.8     4658                 10M
# 3               TikTok          Game     2.8     5646                 20M
# 4             Snapchat  Productivity     4.6     8496                 30M
# 5              Spotify          Game     1.1     1416                 10M
# 6              Netflix        Health     2.2     9243                 10M
# 7              YouTube        Health     2.6     1149  Varies with device
# 8                Gmail        Health     1.0     1242                 30M
# 9          Google Maps        Health     4.0     3596                 20M
# 10     Amazon Shopping          Game     3.8     7444                 20M
# 11             Twitter     Education     2.3     5514                 30M
# ...

# %%
df["App"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: App, dtype: bool

# %%
df["App"].duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset=["App"]) # deletes the row where duplication exists in this column
# Out:
#                    App      Category  Rating  Reviews                Size  \
# 0             Facebook          Game     4.8     8073                 20M
# 1            Instagram     Education     2.6     6813                 30M
# 2   WhatsApp Messenger          Game     3.8     4658                 10M
# 3               TikTok          Game     2.8     5646                 20M
# 4             Snapchat  Productivity     4.6     8496                 30M
# 5              Spotify          Game     1.1     1416                 10M
# 6              Netflix        Health     2.2     9243                 10M
# 7              YouTube        Health     2.6     1149  Varies with device
# 8                Gmail        Health     1.0     1242                 30M
# 9          Google Maps        Health     4.0     3596                 20M
# 10     Amazon Shopping          Game     3.8     7444                 20M
# 11             Twitter     Education     2.3     5514                 30M
# ...

# %%
# df.drop_duplicates(subset=["App"]) # deletes the row where duplication exists in this column

# %%
df["Rating"].isnull().sum()
# Out:
# 0

# %%
# df["Rating"].fillna()

# %%
df["Rating"].mean()
# Out:
# 3.07

# %%
df["Reviews"]
# Out:
# 0     8073
# 1     6813
# 2     4658
# 3     5646
# 4     8496
# 5     1416
# 6     9243
# 7     1149
# 8     1242
# 9     3596
# 10    7444
# 11    5514
# 12    8603
# 13    8023
# 14     364
# 15    7891
# 16    6695
# 17    6286
# 18    6506
# 19    6027
# 20    5227
# 21    2839
# 22    4045
# 23     417
# 24    4835
# 25    8053
# 26     707
# 27    9940
# 28    6254
# 29    8459
# Name: Reviews, dtype: int64
