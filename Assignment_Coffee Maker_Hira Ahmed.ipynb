# %%
# Your task for this week is to develop a program called "Coffee Maker." 
# To complete this project, you must use user-defined functions. 
# This assignment will be used to assess your performance and will contribute to your final grade.

# %%
import pandas as pd
import numpy as np

# %%
# Define the dictionary
coffee_maker = {
    'Menu': [f'Coffee_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Espresso', 'Americano', 'Latte', 'Cappuccino', 'Mocha', 'Macchiato', 'Flat White', 'Iced Coffee'], 30),
    'Price': np.random.choice([5.99, 8.99, 10.00, 15.99], 30),
    'Description': np.random.choice(['Hot', 'Cold'], 30),
    'Size': np.random.choice(['Small', 'Medium', 'Large'], 30),
    'Extras': np.random.choice(['Extra Shot', 'Flavor Syrup', 'Almond Milk', 'Oat Milk', 'Soy Milk'], 30),
    'Availability': np.random.choice(['Available', 'Out of stock'], 30)
}

# Print the dictionary
coffee_maker
# Out:
# {'Menu': ['Coffee_1',
#   'Coffee_2',
#   'Coffee_3',
#   'Coffee_4',
#   'Coffee_5',
#   'Coffee_6',
#   'Coffee_7',
#   'Coffee_8',
#   'Coffee_9',
#   'Coffee_10',
#   'Coffee_11',
#   'Coffee_12',
#   'Coffee_13',
#   'Coffee_14',
#   'Coffee_15',
#   'Coffee_16',
#   'Coffee_17',
#   'Coffee_18',
#   'Coffee_19',
#   'Coffee_20',
#   'Coffee_21',
#   'Coffee_22',
#   'Coffee_23',
#   'Coffee_24',
#   'Coffee_25',
#   'Coffee_26',
#   'Coffee_27',
#   'Coffee_28',
#   'Coffee_29',
#   'Coffee_30'],
#  'Category': array(['Flat White', 'Mocha', 'Espresso', 'Macchiato', 'Mocha',
#         'Cappuccino', 'Americano', 'Mocha', 'Latte', 'Espresso',
#         'Espresso', 'Macchiato', 'Mocha', 'Flat White', 'Mocha', 'Latte',
#         'Cappuccino', 'Mocha', 'Iced Coffee', 'Americano', 'Macchiato',
#         'Americano', 'Americano', 'Latte', 'Flat White', 'Americano',
#         'Iced Coffee', 'Flat White', 'Macchiato', 'Cappuccino'],
#        dtype='<U11'),
# ...

# %%
df = pd.DataFrame(coffee_maker)
df
# Out:
#          Menu     Category  Price Description    Size        Extras  \
# 0    Coffee_1   Flat White  10.00         Hot   Small    Extra Shot
# 1    Coffee_2        Mocha   8.99         Hot   Large    Extra Shot
# 2    Coffee_3     Espresso   5.99         Hot   Small   Almond Milk
# 3    Coffee_4    Macchiato  15.99        Cold   Small   Almond Milk
# 4    Coffee_5        Mocha  15.99         Hot  Medium      Oat Milk
# 5    Coffee_6   Cappuccino  10.00        Cold   Small      Oat Milk
# 6    Coffee_7    Americano  15.99         Hot  Medium  Flavor Syrup
# 7    Coffee_8        Mocha   8.99        Cold   Small   Almond Milk
# 8    Coffee_9        Latte  10.00        Cold   Small   Almond Milk
# 9   Coffee_10     Espresso   5.99         Hot  Medium    Extra Shot
# 10  Coffee_11     Espresso   5.99         Hot   Large    Extra Shot
# 11  Coffee_12    Macchiato   8.99        Cold   Small   Almond Milk
# 12  Coffee_13        Mocha   5.99        Cold  Medium      Oat Milk
# ...

# %%
Coffee_Menu = [
    "Espresso", "Americano", "Latte", "Cappuccino", "Mocha", 
    "Macchiato", "Flat White", "Iced Coffee", "Turkish Coffee", 
    "Irish Coffee", "Affogato", "Ristretto", "Long Black", 
    "Vienna Coffee", "Red Eye", "Black Eye", "White Eye", 
    "Café au Lait", "Café Bombón", "Café Cubano", 
    "Café con Leche", "Café del Tiempo", "Café de Olla", 
    "Café de olla con Leche", "Café de olla con Vainilla", 
    "Café Latte", "Café Miel", "Café Touba", "Café Zorro",
    "Dalgona Coffee"]
df['Menu'] = Coffee_Menu

# %%
df
# Out:
#                          Menu     Category  Price Description    Size  \
# 0                    Espresso   Flat White  10.00         Hot   Small
# 1                   Americano        Mocha   8.99         Hot   Large
# 2                       Latte     Espresso   5.99         Hot   Small
# 3                  Cappuccino    Macchiato  15.99        Cold   Small
# 4                       Mocha        Mocha  15.99         Hot  Medium
# 5                   Macchiato   Cappuccino  10.00        Cold   Small
# 6                  Flat White    Americano  15.99         Hot  Medium
# 7                 Iced Coffee        Mocha   8.99        Cold   Small
# 8              Turkish Coffee        Latte  10.00        Cold   Small
# 9                Irish Coffee     Espresso   5.99         Hot  Medium
# 10                   Affogato     Espresso   5.99         Hot   Large
# 11                  Ristretto    Macchiato   8.99        Cold   Small
# ...
