# %% [markdown]
# DATA SETS AND FRAMES

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'App': [f'App_{i}' for i in range(1, 31)],
    'Category': np.random.choice(['Game', 'Productivity', 'Health', 'Education'], 30),
    'Rating': np.random.uniform(1.0, 5.0, 30).round(1),
    'Reviews': np.random.randint(1, 10000, 30),
    'Size': np.random.choice(['Varies with device', '10M', '20M', '30M'], 30),
    'Installs': np.random.choice(['1,000+', '10,000+', '50,000+', '100,000+'], 30),
    'Type': np.random.choice(['Free', 'Paid'], 30),
    'Price': np.random.choice(['0', '0.99', '1.99', '2.99', '4.99', '5.99', '9.99'], 30),
    'Content Rating': np.random.choice(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+'], 30)
}
data
# Out:
# {'App': ['App_1',
#   'App_2',
#   'App_3',
#   'App_4',
#   'App_5',
#   'App_6',
#   'App_7',
#   'App_8',
#   'App_9',
#   'App_10',
#   'App_11',
#   'App_12',
#   'App_13',
#   'App_14',
#   'App_15',
#   'App_16',
#   'App_17',
#   'App_18',
#   'App_19',
#   'App_20',
#   'App_21',
#   'App_22',
#   'App_23',
#   'App_24',
#   'App_25',
#   'App_26',
#   'App_27',
#   'App_28',
#   'App_29',
#   'App_30'],
#  'Category': array(['Game', 'Game', 'Health', 'Productivity', 'Productivity', 'Health',
#         'Education', 'Education', 'Game', 'Productivity', 'Productivity',
#         'Productivity', 'Education', 'Productivity', 'Education',
#         'Education', 'Productivity', 'Productivity', 'Education',
#         'Education', 'Productivity', 'Health', 'Productivity', 'Game',
#         'Health', 'Education', 'Productivity', 'Game', 'Health', 'Health'],
#        dtype='<U12'),
#  'Rating': array([1.2, 1.2, 2.9, 1.8, 3.1, 3.9, 3.2, 4.6, 1. , 2.7, 1.5, 2. , 2.1,
#         5. , 3.5, 3. , 3.3, 3.5, 3.3, 3.3, 3.8, 1.5, 2.3, 2.3, 4.8, 4.3,
#         3.9, 3.3, 1.4, 1.5]),
#  'Reviews': array([1978, 9471,  140, 9282, 8098, 3927, 5372, 1957, 9198,  373, 4892,
#          625, 9953, 5466, 6344, 7001, 4709, 9774, 3317, 1566, 8333,   19,
#         3216, 9405,  101, 2627, 1374, 6957, 2399, 2527]),
#  'Size': array(['10M', '10M', '20M', '10M', '30M', '30M', '30M',
#         'Varies with device', '30M', '30M', 'Varies with device', '30M',
#         '10M', '30M', '10M', '20M', '30M', '20M', '10M',
#         'Varies with device', 'Varies with device', '10M', '20M', '30M',
#         '20M', 'Varies with device', '10M', 'Varies with device', '30M',
#         '20M'], dtype='<U18'),
#  'Installs': array(['50,000+', '50,000+', '100,000+', '50,000+', '50,000+', '10,000+',
#         '1,000+', '100,000+', '50,000+', '50,000+', '10,000+', '10,000+',
#         '50,000+', '1,000+', '10,000+', '1,000+', '1,000+', '10,000+',
#         '50,000+', '50,000+', '10,000+', '1,000+', '50,000+', '100,000+',
#         '50,000+', '100,000+', '50,000+', '50,000+', '10,000+', '50,000+'],
#        dtype='<U8'),
#  'Type': array(['Free', 'Paid', 'Free', 'Paid', 'Free', 'Free', 'Paid', 'Paid',
#         'Free', 'Paid', 'Free', 'Free', 'Free', 'Paid', 'Free', 'Paid',
#         'Free', 'Free', 'Paid', 'Paid', 'Paid', 'Paid', 'Paid', 'Free',
#         'Free', 'Paid', 'Paid', 'Free', 'Paid', 'Paid'], dtype='<U4'),
#  'Price': array(['0.99', '4.99', '0.99', '4.99', '0', '4.99', '2.99', '0.99',
#         '0.99', '2.99', '0', '1.99', '0.99', '5.99', '2.99', '9.99',
#         '1.99', '0.99', '9.99', '0.99', '0.99', '2.99', '5.99', '0.99',
#         '2.99', '5.99', '5.99', '0.99', '0.99', '4.99'], dtype='<U4'),
#  'Content Rating': array(['Mature 17+', 'Everyone 10+', 'Everyone 10+', 'Everyone',
#         'Mature 17+', 'Teen', 'Teen', 'Teen', 'Everyone 10+', 'Everyone',
#         'Everyone 10+', 'Everyone 10+', 'Teen', 'Everyone', 'Everyone',
#         'Everyone 10+', 'Everyone 10+', 'Everyone 10+', 'Mature 17+',
#         'Everyone 10+', 'Everyone', 'Mature 17+', 'Everyone 10+', 'Teen',
#         'Everyone 10+', 'Everyone 10+', 'Mature 17+', 'Mature 17+',
#         'Everyone', 'Teen'], dtype='<U12')}

# %%
type(data)
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 0    App_1          Game     1.2     1978                 10M   50,000+  Free
# 1    App_2          Game     1.2     9471                 10M   50,000+  Paid
# 2    App_3        Health     2.9      140                 20M  100,000+  Free
# 3    App_4  Productivity     1.8     9282                 10M   50,000+  Paid
# 4    App_5  Productivity     3.1     8098                 30M   50,000+  Free
# 5    App_6        Health     3.9     3927                 30M   10,000+  Free
# 6    App_7     Education     3.2     5372                 30M    1,000+  Paid
# 7    App_8     Education     4.6     1957  Varies with device  100,000+  Paid
# 8    App_9          Game     1.0     9198                 30M   50,000+  Free
# 9   App_10  Productivity     2.7      373                 30M   50,000+  Paid
# 10  App_11  Productivity     1.5     4892  Varies with device   10,000+  Free
# 11  App_12  Productivity     2.0      625                 30M   10,000+  Free
# 12  App_13     Education     2.1     9953                 10M   50,000+  Free
# 13  App_14  Productivity     5.0     5466                 30M    1,000+  Paid
# 14  App_15     Education     3.5     6344                 10M   10,000+  Free
# 15  App_16     Education     3.0     7001                 20M    1,000+  Paid
# 16  App_17  Productivity     3.3     4709                 30M    1,000+  Free
# 17  App_18  Productivity     3.5     9774                 20M   10,000+  Free
# 18  App_19     Education     3.3     3317                 10M   50,000+  Paid
# 19  App_20     Education     3.3     1566  Varies with device   50,000+  Paid
# 20  App_21  Productivity     3.8     8333  Varies with device   10,000+  Paid
# 21  App_22        Health     1.5       19                 10M    1,000+  Paid
# 22  App_23  Productivity     2.3     3216                 20M   50,000+  Paid
# 23  App_24          Game     2.3     9405                 30M  100,000+  Free
# 24  App_25        Health     4.8      101                 20M   50,000+  Free
# 25  App_26     Education     4.3     2627  Varies with device  100,000+  Paid
# 26  App_27  Productivity     3.9     1374                 10M   50,000+  Paid
# 27  App_28          Game     3.3     6957  Varies with device   50,000+  Free
# 28  App_29        Health     1.4     2399                 30M   10,000+  Paid
# 29  App_30        Health     1.5     2527                 20M   50,000+  Paid
#
#    Price Content Rating
# 0   0.99     Mature 17+
# 1   4.99   Everyone 10+
# 2   0.99   Everyone 10+
# 3   4.99       Everyone
# 4      0     Mature 17+
# 5   4.99           Teen
# 6   2.99           Teen
# 7   0.99           Teen
# 8   0.99   Everyone 10+
# 9   2.99       Everyone
# 10     0   Everyone 10+
# 11  1.99   Everyone 10+
# 12  0.99           Teen
# 13  5.99       Everyone
# 14  2.99       Everyone
# 15  9.99   Everyone 10+
# 16  1.99   Everyone 10+
# 17  0.99   Everyone 10+
# 18  9.99     Mature 17+
# 19  0.99   Everyone 10+
# 20  0.99       Everyone
# 21  2.99     Mature 17+
# 22  5.99   Everyone 10+
# 23  0.99           Teen
# 24  2.99   Everyone 10+
# 25  5.99   Everyone 10+
# 26  5.99     Mature 17+
# 27  0.99     Mature 17+
# 28  0.99       Everyone
# 29  4.99           Teen

# %%
df.head()  #first 5 data rows
# Out:
#      App      Category  Rating  Reviews Size  Installs  Type Price  \
# 0  App_1          Game     1.2     1978  10M   50,000+  Free  0.99
# 1  App_2          Game     1.2     9471  10M   50,000+  Paid  4.99
# 2  App_3        Health     2.9      140  20M  100,000+  Free  0.99
# 3  App_4  Productivity     1.8     9282  10M   50,000+  Paid  4.99
# 4  App_5  Productivity     3.1     8098  30M   50,000+  Free     0
#
#   Content Rating
# 0     Mature 17+
# 1   Everyone 10+
# 2   Everyone 10+
# 3       Everyone
# 4     Mature 17+

# %%
df.tail() #last 5 data rows
# Out:
#        App      Category  Rating  Reviews                Size  Installs  Type  \
# 25  App_26     Education     4.3     2627  Varies with device  100,000+  Paid
# 26  App_27  Productivity     3.9     1374                 10M   50,000+  Paid
# 27  App_28          Game     3.3     6957  Varies with device   50,000+  Free
# 28  App_29        Health     1.4     2399                 30M   10,000+  Paid
# 29  App_30        Health     1.5     2527                 20M   50,000+  Paid
#
#    Price Content Rating
# 25  5.99   Everyone 10+
# 26  5.99     Mature 17+
# 27  0.99     Mature 17+
# 28  0.99       Everyone
# 29  4.99           Teen

# %%
df.head(10)
# Out:
#       App      Category  Rating  Reviews                Size  Installs  Type  \
# 0   App_1          Game     1.2     1978                 10M   50,000+  Free
# 1   App_2          Game     1.2     9471                 10M   50,000+  Paid
# 2   App_3        Health     2.9      140                 20M  100,000+  Free
# 3   App_4  Productivity     1.8     9282                 10M   50,000+  Paid
# 4   App_5  Productivity     3.1     8098                 30M   50,000+  Free
# 5   App_6        Health     3.9     3927                 30M   10,000+  Free
# 6   App_7     Education     3.2     5372                 30M    1,000+  Paid
# 7   App_8     Education     4.6     1957  Varies with device  100,000+  Paid
# 8   App_9          Game     1.0     9198                 30M   50,000+  Free
# 9  App_10  Productivity     2.7      373                 30M   50,000+  Paid
#
#   Price Content Rating
# 0  0.99     Mature 17+
# 1  4.99   Everyone 10+
# 2  0.99   Everyone 10+
# 3  4.99       Everyone
# 4     0     Mature 17+
# 5  4.99           Teen
# 6  2.99           Teen
# 7  0.99           Teen
# 8  0.99   Everyone 10+
# 9  2.99       Everyone

# %%
df.info() #metadata or characteristics of data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             30 non-null     object
#  1   Category        30 non-null     object
#  2   Rating          30 non-null     float64
#  3   Reviews         30 non-null     int32
#  4   Size            30 non-null     object
#  5   Installs        30 non-null     object
#  6   Type            30 non-null     object
#  7   Price           30 non-null     object
#  8   Content Rating  30 non-null     object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 2.1+ KB

# %%
df['Price'] #accessing a column in data
# Out:
# 0     0.99
# 1     4.99
# 2     0.99
# 3     4.99
# 4        0
# 5     4.99
# 6     2.99
# 7     0.99
# 8     0.99
# 9     2.99
# 10       0
# 11    1.99
# 12    0.99
# 13    5.99
# 14    2.99
# 15    9.99
# 16    1.99
# 17    0.99
# 18    9.99
# 19    0.99
# 20    0.99
# 21    2.99
# 22    5.99
# 23    0.99
# 24    2.99
# 25    5.99
# 26    5.99
# 27    0.99
# 28    0.99
# 29    4.99
# Name: Price, dtype: object

# %%
df['App']
# Out:
# 0      App_1
# 1      App_2
# 2      App_3
# 3      App_4
# 4      App_5
# 5      App_6
# 6      App_7
# 7      App_8
# 8      App_9
# 9     App_10
# 10    App_11
# 11    App_12
# 12    App_13
# 13    App_14
# 14    App_15
# 15    App_16
# 16    App_17
# 17    App_18
# 18    App_19
# 19    App_20
# 20    App_21
# 21    App_22
# 22    App_23
# 23    App_24
# 24    App_25
# 25    App_26
# 26    App_27
# 27    App_28
# 28    App_29
# 29    App_30
# Name: App, dtype: object

# %%
df['App'].replace('App_1','FoodPanda')
# Out:
# 0     FoodPanda
# 1         App_2
# 2         App_3
# 3         App_4
# 4         App_5
# 5         App_6
# 6         App_7
# 7         App_8
# 8         App_9
# 9        App_10
# 10       App_11
# 11       App_12
# 12       App_13
# 13       App_14
# 14       App_15
# 15       App_16
# 16       App_17
# 17       App_18
# 18       App_19
# 19       App_20
# 20       App_21
# 21       App_22
# 22       App_23
# 23       App_24
# 24       App_25
# 25       App_26
# 26       App_27
# 27       App_28
# 28       App_29
# 29       App_30
# Name: App, dtype: object

# %%
df['Price'].replace('0','Free')
# Out:
# 0     0.99
# 1     4.99
# 2     0.99
# 3     4.99
# 4     Free
# 5     4.99
# 6     2.99
# 7     0.99
# 8     0.99
# 9     2.99
# 10    Free
# 11    1.99
# 12    0.99
# 13    5.99
# 14    2.99
# 15    9.99
# 16    1.99
# 17    0.99
# 18    9.99
# 19    0.99
# 20    0.99
# 21    2.99
# 22    5.99
# 23    0.99
# 24    2.99
# 25    5.99
# 26    5.99
# 27    0.99
# 28    0.99
# 29    4.99
# Name: Price, dtype: object

# %%
playstore_apps = [
    "Facebook",
    "Instagram",
    "WhatsApp Messenger",
    "TikTok",
    "Snapchat",
    "Spotify",
    "Netflix",
    "YouTube",
    "Gmail",
    "Google Maps",
    "Amazon Shopping",
    "Twitter",
    "Zoom",
    "Microsoft Teams",
    "Disney+",
    "Pinterest",
    "Reddit",
    "LinkedIn",
    "Uber",
    "Airbnb",
    "Google Drive",
    "Microsoft Word",
    "Google Photos",
    "Dropbox",
    "Evernote",
    "Skype",
    "Telegram",
    "Slack",
    "Tinder",
    "Duolingo"
]

# %%
df['App'] = playstore_apps

# %%
df
# Out:
#                    App      Category  Rating  Reviews                Size  \
# 0             Facebook          Game     1.2     1978                 10M
# 1            Instagram          Game     1.2     9471                 10M
# 2   WhatsApp Messenger        Health     2.9      140                 20M
# 3               TikTok  Productivity     1.8     9282                 10M
# 4             Snapchat  Productivity     3.1     8098                 30M
# 5              Spotify        Health     3.9     3927                 30M
# 6              Netflix     Education     3.2     5372                 30M
# 7              YouTube     Education     4.6     1957  Varies with device
# 8                Gmail          Game     1.0     9198                 30M
# 9          Google Maps  Productivity     2.7      373                 30M
# 10     Amazon Shopping  Productivity     1.5     4892  Varies with device
# 11             Twitter  Productivity     2.0      625                 30M
# 12                Zoom     Education     2.1     9953                 10M
# 13     Microsoft Teams  Productivity     5.0     5466                 30M
# 14             Disney+     Education     3.5     6344                 10M
# 15           Pinterest     Education     3.0     7001                 20M
# 16              Reddit  Productivity     3.3     4709                 30M
# 17            LinkedIn  Productivity     3.5     9774                 20M
# 18                Uber     Education     3.3     3317                 10M
# 19              Airbnb     Education     3.3     1566  Varies with device
# 20        Google Drive  Productivity     3.8     8333  Varies with device
# 21      Microsoft Word        Health     1.5       19                 10M
# 22       Google Photos  Productivity     2.3     3216                 20M
# 23             Dropbox          Game     2.3     9405                 30M
# 24            Evernote        Health     4.8      101                 20M
# 25               Skype     Education     4.3     2627  Varies with device
# 26            Telegram  Productivity     3.9     1374                 10M
# 27               Slack          Game     3.3     6957  Varies with device
# 28              Tinder        Health     1.4     2399                 30M
# 29            Duolingo        Health     1.5     2527                 20M
#
#     Installs  Type Price Content Rating
# 0    50,000+  Free  0.99     Mature 17+
# 1    50,000+  Paid  4.99   Everyone 10+
# 2   100,000+  Free  0.99   Everyone 10+
# 3    50,000+  Paid  4.99       Everyone
# 4    50,000+  Free     0     Mature 17+
# 5    10,000+  Free  4.99           Teen
# 6     1,000+  Paid  2.99           Teen
# 7   100,000+  Paid  0.99           Teen
# 8    50,000+  Free  0.99   Everyone 10+
# 9    50,000+  Paid  2.99       Everyone
# 10   10,000+  Free     0   Everyone 10+
# 11   10,000+  Free  1.99   Everyone 10+
# 12   50,000+  Free  0.99           Teen
# 13    1,000+  Paid  5.99       Everyone
# 14   10,000+  Free  2.99       Everyone
# 15    1,000+  Paid  9.99   Everyone 10+
# 16    1,000+  Free  1.99   Everyone 10+
# 17   10,000+  Free  0.99   Everyone 10+
# 18   50,000+  Paid  9.99     Mature 17+
# 19   50,000+  Paid  0.99   Everyone 10+
# 20   10,000+  Paid  0.99       Everyone
# 21    1,000+  Paid  2.99     Mature 17+
# 22   50,000+  Paid  5.99   Everyone 10+
# 23  100,000+  Free  0.99           Teen
# 24   50,000+  Free  2.99   Everyone 10+
# 25  100,000+  Paid  5.99   Everyone 10+
# 26   50,000+  Paid  5.99     Mature 17+
# 27   50,000+  Free  0.99     Mature 17+
# 28   10,000+  Paid  0.99       Everyone
# 29   50,000+  Paid  4.99           Teen

# %%
df['Content Rating']=df["Content Rating"].replace("Mature 17+","Mature18+")
df
# Out:
#                    App      Category  Rating  Reviews                Size  \
# 0             Facebook          Game     1.2     1978                 10M
# 1            Instagram          Game     1.2     9471                 10M
# 2   WhatsApp Messenger        Health     2.9      140                 20M
# 3               TikTok  Productivity     1.8     9282                 10M
# 4             Snapchat  Productivity     3.1     8098                 30M
# 5              Spotify        Health     3.9     3927                 30M
# 6              Netflix     Education     3.2     5372                 30M
# 7              YouTube     Education     4.6     1957  Varies with device
# 8                Gmail          Game     1.0     9198                 30M
# 9          Google Maps  Productivity     2.7      373                 30M
# 10     Amazon Shopping  Productivity     1.5     4892  Varies with device
# 11             Twitter  Productivity     2.0      625                 30M
# 12                Zoom     Education     2.1     9953                 10M
# 13     Microsoft Teams  Productivity     5.0     5466                 30M
# 14             Disney+     Education     3.5     6344                 10M
# 15           Pinterest     Education     3.0     7001                 20M
# 16              Reddit  Productivity     3.3     4709                 30M
# 17            LinkedIn  Productivity     3.5     9774                 20M
# 18                Uber     Education     3.3     3317                 10M
# 19              Airbnb     Education     3.3     1566  Varies with device
# 20        Google Drive  Productivity     3.8     8333  Varies with device
# 21      Microsoft Word        Health     1.5       19                 10M
# 22       Google Photos  Productivity     2.3     3216                 20M
# 23             Dropbox          Game     2.3     9405                 30M
# 24            Evernote        Health     4.8      101                 20M
# 25               Skype     Education     4.3     2627  Varies with device
# 26            Telegram  Productivity     3.9     1374                 10M
# 27               Slack          Game     3.3     6957  Varies with device
# 28              Tinder        Health     1.4     2399                 30M
# 29            Duolingo        Health     1.5     2527                 20M
#
#     Installs  Type Price Content Rating
# 0    50,000+  Free  0.99     Mature 18+
# 1    50,000+  Paid  4.99   Everyone 10+
# 2   100,000+  Free  0.99   Everyone 10+
# 3    50,000+  Paid  4.99       Everyone
# 4    50,000+  Free     0     Mature 18+
# 5    10,000+  Free  4.99           Teen
# 6     1,000+  Paid  2.99           Teen
# 7   100,000+  Paid  0.99           Teen
# 8    50,000+  Free  0.99   Everyone 10+
# 9    50,000+  Paid  2.99       Everyone
# 10   10,000+  Free     0   Everyone 10+
# 11   10,000+  Free  1.99   Everyone 10+
# 12   50,000+  Free  0.99           Teen
# 13    1,000+  Paid  5.99       Everyone
# 14   10,000+  Free  2.99       Everyone
# 15    1,000+  Paid  9.99   Everyone 10+
# 16    1,000+  Free  1.99   Everyone 10+
# 17   10,000+  Free  0.99   Everyone 10+
# 18   50,000+  Paid  9.99     Mature 18+
# 19   50,000+  Paid  0.99   Everyone 10+
# 20   10,000+  Paid  0.99       Everyone
# 21    1,000+  Paid  2.99     Mature 18+
# 22   50,000+  Paid  5.99   Everyone 10+
# 23  100,000+  Free  0.99           Teen
# 24   50,000+  Free  2.99   Everyone 10+
# 25  100,000+  Paid  5.99   Everyone 10+
# 26   50,000+  Paid  5.99     Mature 18+
# 27   50,000+  Free  0.99     Mature 18+
# 28   10,000+  Paid  0.99       Everyone
# 29   50,000+  Paid  4.99           Teen

# %%
df["App"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: App, dtype: bool

# %%
df["App"].duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(subset=["App"]) # deletes the row where duplication exists in this column
# Out:
#                    App      Category  Rating  Reviews                Size  \
# 0             Facebook          Game     1.2     1978                 10M
# 1            Instagram          Game     1.2     9471                 10M
# 2   WhatsApp Messenger        Health     2.9      140                 20M
# 3               TikTok  Productivity     1.8     9282                 10M
# 4             Snapchat  Productivity     3.1     8098                 30M
# 5              Spotify        Health     3.9     3927                 30M
# 6              Netflix     Education     3.2     5372                 30M
# 7              YouTube     Education     4.6     1957  Varies with device
# 8                Gmail          Game     1.0     9198                 30M
# 9          Google Maps  Productivity     2.7      373                 30M
# 10     Amazon Shopping  Productivity     1.5     4892  Varies with device
# 11             Twitter  Productivity     2.0      625                 30M
# 12                Zoom     Education     2.1     9953                 10M
# 13     Microsoft Teams  Productivity     5.0     5466                 30M
# 14             Disney+     Education     3.5     6344                 10M
# 15           Pinterest     Education     3.0     7001                 20M
# 16              Reddit  Productivity     3.3     4709                 30M
# 17            LinkedIn  Productivity     3.5     9774                 20M
# 18                Uber     Education     3.3     3317                 10M
# 19              Airbnb     Education     3.3     1566  Varies with device
# 20        Google Drive  Productivity     3.8     8333  Varies with device
# 21      Microsoft Word        Health     1.5       19                 10M
# 22       Google Photos  Productivity     2.3     3216                 20M
# 23             Dropbox          Game     2.3     9405                 30M
# 24            Evernote        Health     4.8      101                 20M
# 25               Skype     Education     4.3     2627  Varies with device
# 26            Telegram  Productivity     3.9     1374                 10M
# 27               Slack          Game     3.3     6957  Varies with device
# 28              Tinder        Health     1.4     2399                 30M
# 29            Duolingo        Health     1.5     2527                 20M
#
#     Installs  Type Price Content Rating
# 0    50,000+  Free  0.99     Mature 18+
# 1    50,000+  Paid  4.99   Everyone 10+
# 2   100,000+  Free  0.99   Everyone 10+
# 3    50,000+  Paid  4.99       Everyone
# 4    50,000+  Free     0     Mature 18+
# 5    10,000+  Free  4.99           Teen
# 6     1,000+  Paid  2.99           Teen
# 7   100,000+  Paid  0.99           Teen
# 8    50,000+  Free  0.99   Everyone 10+
# 9    50,000+  Paid  2.99       Everyone
# 10   10,000+  Free     0   Everyone 10+
# 11   10,000+  Free  1.99   Everyone 10+
# 12   50,000+  Free  0.99           Teen
# 13    1,000+  Paid  5.99       Everyone
# 14   10,000+  Free  2.99       Everyone
# 15    1,000+  Paid  9.99   Everyone 10+
# 16    1,000+  Free  1.99   Everyone 10+
# 17   10,000+  Free  0.99   Everyone 10+
# 18   50,000+  Paid  9.99     Mature 18+
# 19   50,000+  Paid  0.99   Everyone 10+
# 20   10,000+  Paid  0.99       Everyone
# 21    1,000+  Paid  2.99     Mature 18+
# 22   50,000+  Paid  5.99   Everyone 10+
# 23  100,000+  Free  0.99           Teen
# 24   50,000+  Free  2.99   Everyone 10+
# 25  100,000+  Paid  5.99   Everyone 10+
# 26   50,000+  Paid  5.99     Mature 18+
# 27   50,000+  Free  0.99     Mature 18+
# 28   10,000+  Paid  0.99       Everyone
# 29   50,000+  Paid  4.99           Teen

# %%
# df.drop_duplicates(subset=["App"]) # deletes the row where duplication exists in this column
