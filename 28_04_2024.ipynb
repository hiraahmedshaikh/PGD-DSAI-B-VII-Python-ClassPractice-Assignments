# %%
Age = int(input("Enter your Age : "))

if Age >=18:
  print("you are eligible for Voting")
else:
  print("you are not eligible  for Voting")
# Out:
# Enter your Age : 24
# you are eligible for Voting

# %%
num = int(input("Enter number : "))
if num > 0:
  print("positive")
elif num == 0:
  print("null")
else:
  print("negative")
# Out:
# Enter number : 2
# positive

# %%
num = int(input("Enter number : "))

if num > 0:
  print("positive")
elif num == 0:
  print("null")
else:
  print("negative")
# Out:
# Enter number : 2
# positive

# %%
num = int(input("Enter number : "))

if num > 0:
  print("positive")
elif num == 0:
  print("null")
else:
  print("negative")
# Out:
# Enter number : 0
# null

# %%
num = int(input("Enter number : "))

if num > 0:
  print("positive")
elif num == 0:
  print("null")
else:
  print("negative")
# Out:
# Enter number : -3
# negative

# %%
num = input("Enter number : ")

if num == str(): #dont input anything just enter. not even space as space is counted as character.
  print("Enter a valid number")

elif int(num)>0:
  print("positive")
elif int(num) == 0:
  print("null")
else:
  print("negative")
# Out:
# Enter number : 1
# positive

# %%
num = input("Enter number : ")

if not num.isdigit(): #if integer is true or false
  print("Enter a valid number")

elif int(num)>0:
  print("positive")
elif int(num) == 0:
  print("null")
else:
  print("negative")
# Out:
# Enter number : !
# Enter a valid number

# %%
a = input("Enter value for a : ")
b = input("Enter value for b : ")
print('a and b is',a and b)
print('a or b is',a or b)
print('not a is',not a)
# Out:
# Enter value for a : False
# Enter value for b : True
# a and b is True
# a or b is False
# not a is False

# %%
a = input("Education Requirement : ")
b = input("Enter your Qualification : ")
if a is b: #identity operators
  print('you are eligible')
else:
  print('you are not eligible')
# Out:
# Education Requirement : MBA
# Enter your Qualification : BBA
# you are not eligible

# %%
my_edu = input("Enter your Education Qualification : ")
org_req = "MBA"
if my_edu is not org_req: #identity operators
  print('you are eligible')
else:
  print('you are not eligible')
# Out:
# Enter your Education Qualification : c
# you are eligible

# %%
my_edu = input("Enter your Education Qualification : ")
org_req = "MBA" #it doesnt return correct value becuase it has more charcter. works well with int
if my_edu is not org_req: #identity operators
  print('you are eligible')
else:
  print('you are not eligible')
# Out:
# Enter your Education Qualification : BBA
# you are eligible

# %%
my_age = int(input("Enter your Age : "))
org_req = "30"
if my_edu is org_req: #identity operators
  print('you are eligible')
else:
  print('you are not eligible')
# Out:
# Enter your Age : 30
# you are not eligible
